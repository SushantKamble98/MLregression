# %%
import pandas as pd
df=pd.read_csv("house_price.csv")
df
# Out:
#      Flat_Price  EMI_Starts    BHK  css-11nfaq3 Unnamed: 4         HOUSE_TYPE  \
# 0       ₹8.5 Cr  ₹4.22 Lacs  6 BHK          6.0        BHK  Independent House
# 1       ₹45.0 L    ₹23.83 K  3 BHK          3.0        BHK  Independent House
# 2      ₹1.35 Cr    ₹67.02 K  3 BHK          3.0        BHK  Independent House
# 3       ₹60.0 L    ₹31.77 K  5 BHK          5.0        BHK  Independent House
# 4       ₹52.0 L    ₹27.54 K  4 BHK          4.0        BHK  Independent House
# ...         ...         ...    ...          ...        ...                ...
# 3963    ₹13.0 L     ₹6.88 K  2 BHK          2.0        BHK  Independent House
# 3964    ₹1.5 Cr    ₹74.47 K  8 BHK          8.0        BHK  Independent House
# 3965    ₹50.0 L    ₹26.48 K  5 BHK          5.0        BHK  Independent House
# 3966    ₹1.1 Cr    ₹54.61 K  5 BHK          5.0        BHK  Independent House
# 3967    ₹30.0 L    ₹15.89 K  2 BHK          2.0        BHK  Independent House
#
# ...

# %%
df.isnull().sum()
# Out:
# Flat_Price          0
# EMI_Starts          0
# BHK                 0
# css-11nfaq3         2
# Unnamed: 4          2
# HOUSE_TYPE          0
# Unnamed: 6          2
# Unnamed: 7          2
# Purpose             2
# Location            2
# Area_Type           0
# Total_Sq.ft         0
# Price_per_sq.ft     0
# Owner_name         10
# Owner_type          0
# dtype: int64

# %%
df.shape
# Out:
# (3968, 15)

# %%
df = df.drop("css-11nfaq3", axis=1)

# %%
df.shape
# Out:
# (3968, 14)

# %%
df.isnull().sum()
# Out:
# Flat_Price          0
# EMI_Starts          0
# BHK                 0
# Unnamed: 4          2
# HOUSE_TYPE          0
# Unnamed: 6          2
# Unnamed: 7          2
# Purpose             2
# Location            2
# Area_Type           0
# Total_Sq.ft         0
# Price_per_sq.ft     0
# Owner_name         10
# Owner_type          0
# dtype: int64

# %%
df.to_csv("EDA_House_price.csv", index=False)

# %%
df = pd.read_csv("EDA_House_price.csv")
df
# Out:
#      Flat_Price  EMI_Starts    BHK Unnamed: 4         HOUSE_TYPE   Unnamed: 6  \
# 0       ₹8.5 Cr  ₹4.22 Lacs  6 BHK        BHK  Independent House  Independent
# 1       ₹45.0 L    ₹23.83 K  3 BHK        BHK  Independent House  Independent
# 2      ₹1.35 Cr    ₹67.02 K  3 BHK        BHK  Independent House  Independent
# 3       ₹60.0 L    ₹31.77 K  5 BHK        BHK  Independent House  Independent
# 4       ₹52.0 L    ₹27.54 K  4 BHK        BHK  Independent House  Independent
# ...         ...         ...    ...        ...                ...          ...
# 3963    ₹13.0 L     ₹6.88 K  2 BHK        BHK  Independent House  Independent
# 3964    ₹1.5 Cr    ₹74.47 K  8 BHK        BHK  Independent House  Independent
# 3965    ₹50.0 L    ₹26.48 K  5 BHK        BHK  Independent House  Independent
# 3966    ₹1.1 Cr    ₹54.61 K  5 BHK        BHK  Independent House  Independent
# 3967    ₹30.0 L    ₹15.89 K  2 BHK        BHK  Independent House  Independent
#
# ...

# %%
df.isnull().sum()
# Out:
# Flat_Price          0
# EMI_Starts          0
# BHK                 0
# Unnamed: 4          2
# HOUSE_TYPE          0
# Unnamed: 6          2
# Unnamed: 7          2
# Purpose             2
# Location            2
# Area_Type           0
# Total_Sq.ft         0
# Price_per_sq.ft     0
# Owner_name         10
# Owner_type          0
# dtype: int64

# %%
df.shape
# Out:
# (3968, 14)

# %%
df = df.drop("css-11nfaq3", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = df.drop("css-11nfaq3", axis=1)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df.shape

# %%
df.to_csv("EDA1_House_price.csv", index=False)

# %%
df = pd.read_csv("EDA1_House_price.csv")
df

# %%
df = df.drop(["Unnamed: 4", "Unnamed: 7"], axis=1)

# %%
df.shape
# Out:
# (3968, 12)

# %%
df.duplicated().sum()
# Out:
# np.int64(2013)

# %%
df[df.duplicated(keep=False)]
# Out:
#      Flat_Price EMI_Starts     BHK         HOUSE_TYPE   Unnamed: 6  \
# 3       ₹60.0 L   ₹31.77 K   5 BHK  Independent House  Independent
# 4       ₹52.0 L   ₹27.54 K   4 BHK  Independent House  Independent
# 5       ₹32.0 L   ₹16.95 K   3 BHK  Independent House  Independent
# 6       ₹69.3 L   ₹36.70 K   3 BHK  Independent House  Independent
# 7       ₹40.0 L   ₹21.18 K   2 BHK  Independent House  Independent
# ...         ...        ...     ...                ...          ...
# 3943    ₹80.0 L   ₹39.72 K  10 BHK  Independent House  Independent
# 3944    ₹31.0 L   ₹16.42 K   1 BHK  Independent House  Independent
# 3945    ₹48.0 L   ₹25.42 K   2 BHK  Independent House  Independent
# 3946    ₹25.0 L   ₹13.24 K   2 BHK  Independent House  Independent
# 3947   ₹1.44 Cr   ₹71.49 K   8 BHK  Independent House  Independent
#
#           Purpose                  Location      Area_Type Total_Sq.ft  \
# 3     for sale in          Sarsuna, Kolkata  Build Up Area  1100 sq.ft
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.scatter(df["BHK"],df["Flat_Price"])
plt.xlabel("BHK")
plt.ylabel("Flat_Price")

# %%
X=df[['Total_Sq.ft']]#independent feature/ i/p
y=df[['Flat_Price']]#dependent feature/ o/p

# %%
x.shape

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=39)

# %%
X_train
